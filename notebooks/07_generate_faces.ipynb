# %% [markdown]
# # 07 Generate Faces
#
# Generate final sample images from the saved generator checkpoint.

# %%
import subprocess
import sys
from pathlib import Path

command = [
    sys.executable,
    '../gan_anime_faces.py',
    'sample',
    '--checkpoint', '../outputs/checkpoints/latest.pt',
    '--output-dir', '../outputs',
    '--num-samples', '64',
]
subprocess.run(command, check=True)

generated_grid = Path('../outputs/samples/generated_grid.png')
generated_grid
