# %% [markdown]
# # 04 Training
#
# Launch DCGAN training from the notebook using the shared CLI entrypoint.

# %%
import subprocess
import sys

command = [
    sys.executable,
    '../gan_anime_faces.py',
    'train',
    '--data-dir', '/kaggle/input/animefacedataset',
    '--output-dir', '../outputs',
    '--epochs', '50',
    '--batch-size', '128',
    '--save-every', '5',
]
subprocess.run(command, check=True)
